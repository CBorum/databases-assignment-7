# %%
# %load_ext sql

# %%
# %sql postgresql://appdev@data:5432/appdev
# Out:
# 'Connected: appdev@appdev'

# %%
# %sql SELECT * from information_schema.tables WHERE table_schema = 'f1db';

# %%
# %sql SELECT * from information_schema.columns WHERE table_schema = 'f1db';

# %% [markdown]
# # 1)
# Using a single join and a grouping, write a query that allows you to find the forename, surname, driverid and the total number of wins for each driver in the f1db schema.

# %%
# %%sql
# SELECT drivers.forename, drivers.surname, drivers.driverid, count(*)
# FROM results
# JOIN drivers ON results.driverid = drivers.driverid
# WHERE position = 1
# GROUP BY drivers.driverid
# ORDER BY count(*) DESC
# LIMIT 25;
# Out:
# 25 rows affected.
# [('Michael', 'Schumacher', 30, 91),
#  ('Lewis', 'Hamilton', 1, 60),
#  ('Alain', 'Prost', 117, 51),
#  ('Sebastian', 'Vettel', 20, 46),
#  ('Ayrton', 'Senna', 102, 41),
#  ('Fernando', 'Alonso', 4, 32),
#  ('Nigel', 'Mansell', 95, 31),
#  ('Jackie', 'Stewart', 328, 27),
#  ('Niki', 'Lauda', 182, 25),
#  ('Jim', 'Clark', 373, 25),
#  ('Juan', 'Fangio', 579, 24),
#  ('Nelson', 'Piquet', 137, 23),
#  ('Nico', 'Rosberg', 3, 23),
#  ('Damon', 'Hill', 71, 22),
#  ('Mika', 'Häkkinen', 57, 20),
#  ('Kimi', 'Räikkönen', 8, 20),
#  ('Stirling', 'Moss', 475, 16),
#  ('Jenson', 'Button', 18, 15),
#  ('Graham', 'Hill', 289, 14),
#  ('Emerson', 'Fittipaldi', 224, 14),
#  ('Jack', 'Brabham', 356, 14),
#  ('David', 'Coulthard', 14, 13),
#  ('Alberto', 'Ascari', 647, 13),
#  ('Carlos', 'Reutemann', 199, 12),
#  ('Alan', 'Jones', 178, 12)]

# %% [markdown]
# # 2)
# Write a query that joins the tables results, constructors and drivers to show the amount of times a driver has driven a car from a constructor. In other words how many times one driver (for instance Schumacher) has driven a constructor (for instance Mercedes). Your table should have three fields: drivers.driverref, constructors.name and count(*) (showing the number of times the driver has driven the constructor).

# %%
# %%sql
# SELECT drivers.driverref, constructors.name, count(*)
# FROM drivers
# JOIN results ON drivers.driverid = results.driverid
# JOIN constructors ON results.constructorid = constructors.constructorid
# GROUP BY drivers.driverref, constructors.name
# ORDER BY count(*) DESC
# LIMIT 25;
# Out:
# 25 rows affected.
# [('michael_schumacher', 'Ferrari', 181),
#  ('coulthard', 'McLaren', 150),
#  ('massa', 'Ferrari', 140),
#  ('button', 'McLaren', 137),
#  ('rosberg', 'Mercedes', 136),
#  ('hakkinen', 'McLaren', 133),
#  ('laffite', 'Ligier', 132),
#  ('webber', 'Red Bull', 129),
#  ('raikkonen', 'Ferrari', 126),
#  ('vettel', 'Red Bull', 113),
#  ('hamilton', 'McLaren', 110),
#  ('prost', 'McLaren', 109),
#  ('alonso', 'Renault', 106),
#  ('martini', 'Minardi', 106),
#  ('barrichello', 'Ferrari', 104),
#  ('mansell', 'Williams', 97),
#  ('berger', 'Ferrari', 96),
#  ('alonso', 'Ferrari', 96),
#  ('senna', 'McLaren', 96),
#  ('ralf_schumacher', 'Williams', 94),
#  ('hamilton', 'Mercedes', 93),
#  ('sutil', 'Force India', 92),
#  ('piquet', 'Brabham', 92),
#  ('trulli', 'Toyota', 91),
#  ('angelis', 'Team Lotus', 91)]

# %% [markdown]
# # 3)
# Now we have found the most driven vehicles even for those who didn't finish the race. Extend the query from 2 by removing all tuples from the result where the status is not "Finished".

# %%
# %%sql
# SELECT drivers.driverref, constructors.name, count(*)
# FROM drivers
# JOIN results ON drivers.driverid = results.driverid
# JOIN constructors ON results.constructorid = constructors.constructorid
# JOIN status ON status.statusid = results.statusid
# WHERE status.status = 'Finished'
# GROUP BY drivers.driverref, constructors.name
# ORDER BY count(*) DESC
# LIMIT 25;
# Out:
# 25 rows affected.
# [('michael_schumacher', 'Ferrari', 141),
#  ('massa', 'Ferrari', 112),
#  ('rosberg', 'Mercedes', 109),
#  ('webber', 'Red Bull', 100),
#  ('vettel', 'Red Bull', 97),
#  ('raikkonen', 'Ferrari', 92),
#  ('alonso', 'Ferrari', 87),
#  ('button', 'McLaren', 87),
#  ('coulthard', 'McLaren', 85),
#  ('hamilton', 'Mercedes', 85),
#  ('hamilton', 'McLaren', 84),
#  ('alonso', 'Renault', 80),
#  ('barrichello', 'Ferrari', 73),
#  ('hakkinen', 'McLaren', 70),
#  ('prost', 'McLaren', 69),
#  ('senna', 'McLaren', 61),
#  ('ricciardo', 'Red Bull', 56),
#  ('ralf_schumacher', 'Williams', 54),
#  ('bottas', 'Williams', 52),
#  ('raikkonen', 'McLaren', 52),
#  ('hulkenberg', 'Force India', 49),
#  ('vettel', 'Ferrari', 48),
#  ('heidfeld', 'BMW Sauber', 47),
#  ('mansell', 'Williams', 46),
#  ('michael_schumacher', 'Benetton', 44)]

# %% [markdown]
# # 4)
# Create a third (and new) query that finds the amount of milliseconds spent in pitstop (see the pitstops relation) by each unique combinations of driverid and raceid.

# %%
# %%sql
# CREATE VIEW pitstop_sum AS SELECT sum(milliseconds), driverid, raceid
# FROM pitstops
# GROUP BY driverid, raceid;

# %%
# %%sql
# SELECT * FROM pitstop_sum
# LIMIT 25;
# Out:
# 25 rows affected.
# [(Decimal('22045'), 815, 969),
#  (Decimal('59281'), 8, 942),
#  (Decimal('24086'), 20, 898),
#  (Decimal('89060'), 8, 913),
#  (Decimal('47766'), 807, 894),
#  (Decimal('21346'), 3, 878),
#  (Decimal('52279'), 807, 953),
#  (Decimal('63197'), 4, 855),
#  (Decimal('44412'), 8, 930),
#  (Decimal('22692'), 819, 876),
#  (Decimal('24840'), 8, 878),
#  (Decimal('79513'), 20, 849),
#  (Decimal('80648'), 830, 970),
#  (Decimal('63202'), 5, 870),
#  (Decimal('45271'), 8, 928),
#  (Decimal('59994'), 817, 888),
#  (Decimal('24214'), 825, 912),
#  (Decimal('46289'), 807, 969),
#  (Decimal('40984'), 3, 870),
#  (Decimal('25798'), 4, 983),
#  (Decimal('29710'), 154, 908),
#  (Decimal('41430'), 1, 856),
#  (Decimal('61905'), 826, 915),
#  (Decimal('125723'), 824, 902),
#  (Decimal('106079'), 811, 861)]

# %% [markdown]
# # 5)
# Time to put everything together. Use the query for 4 as a join subquery in query 3 (see slides on "a query within a query") to find the total amount of pitstop time, for each result in query 3

# %%
# %%sql
# SELECT drivers.driverref, constructors.name, count(*), sum(ps.sum) AS milliseconds
# FROM drivers
# JOIN results ON drivers.driverid = results.driverid
# JOIN constructors ON results.constructorid = constructors.constructorid
# JOIN status ON status.statusid = results.statusid
# JOIN (SELECT * FROM pitstop_sum) AS ps ON ps.driverid = drivers.driverid
# WHERE status.status = 'Finished'
# GROUP BY drivers.driverref, constructors.name
# LIMIT 25;
# Out:
# 25 rows affected.
# [('alguersuari', 'Toro Rosso', 252, Decimal('14365134')),
#  ('alonso', 'Ferrari', 10614, Decimal('1150974156')),
#  ('alonso', 'McLaren', 3538, Decimal('383658052')),
#  ('alonso', 'Renault', 9760, Decimal('1058367040')),
#  ('ambrosio', 'Lotus F1', 18, Decimal('1043218')),
#  ('barrichello', 'Brawn', 288, Decimal('19693616')),
#  ('barrichello', 'Ferrari', 1314, Decimal('89852123')),
#  ('barrichello', 'Honda', 324, Decimal('22155318')),
#  ('barrichello', 'Jordan', 252, Decimal('17231914')),
#  ('barrichello', 'Stewart', 180, Decimal('12308510')),
#  ('barrichello', 'Williams', 252, Decimal('17231914')),
#  ('bottas', 'Mercedes', 1274, Decimal('176270192')),
#  ('bottas', 'Williams', 4732, Decimal('654717856')),
#  ('bruno_senna', 'Renault', 52, Decimal('2920504')),
#  ('bruno_senna', 'Williams', 338, Decimal('18983276')),
#  ('buemi', 'Toro Rosso', 306, Decimal('17729946')),
#  ('button', 'BAR', 2997, Decimal('318619251')),
#  ('button', 'Benetton', 222, Decimal('23601426')),
#  ('button', 'Brawn', 1776, Decimal('188811408')),
#  ('button', 'Honda', 2109, Decimal('224213547')),
#  ('button', 'McLaren', 9657, Decimal('1026662031')),
#  ('button', 'Renault', 666, Decimal('70804278')),
#  ('button', 'Williams', 444, Decimal('47202852')),
#  ('chilton', 'Marussia', 132, Decimal('12848932')),
#  ('ericsson', 'Caterham', 64, Decimal('7216999'))]

# %% [markdown]
# # 6)
# As a last thing we want to find the driver with the least pistop time. However we want to control for the amount of races (see explanation below), so we need to include one last column: the average pitstop time per race. Your table should be sorted based on the ascending values of that average pitstop time.
# Explanation: If we just count the pitstop time, we only get the total time he spend in a workshop, no matter how many races he participated in. If a driver participated in 100 races, he would have more pitstop time than a driver participating in one race!
# Hint: Use the sum function to accumulate the total pistop time and divide that with the amount of races the driver has participated in

# %%
# %%sql
# SELECT drivers.driverref, constructors.name, count(*), sum(ps.sum) AS milliseconds, avg(ps.sum) AS average_milliseconds
# FROM drivers
# JOIN results ON drivers.driverid = results.driverid
# JOIN constructors ON results.constructorid = constructors.constructorid
# JOIN status ON status.statusid = results.statusid
# JOIN (SELECT * FROM pitstop_sum) AS ps ON ps.driverid = drivers.driverid
# WHERE status.status = 'Finished'
# GROUP BY drivers.driverref, constructors.name
# ORDER BY average_milliseconds ASC
# LIMIT 25;
# Out:
# 25 rows affected.
# [('glock', 'Toyota', 792, Decimal('39177512'), Decimal('49466.555555555556')),
#  ('glock', 'Marussia', 72, Decimal('3561592'), Decimal('49466.555555555556')),
#  ('pic', 'Marussia', 74, Decimal('3860832'), Decimal('52173.405405405405')),
#  ('pic', 'Caterham', 74, Decimal('3860832'), Decimal('52173.405405405405')),
#  ('resta', 'Force India', 1972, Decimal('103995834'), Decimal('52736.224137931034')),
#  ('michael_schumacher', 'Mercedes', 1292, Decimal('68977432'), Decimal('53388.105263157895')),
#  ('michael_schumacher', 'Ferrari', 5358, Decimal('286053468'), Decimal('53388.105263157895')),
#  ('michael_schumacher', 'Benetton', 1672, Decimal('89264912'), Decimal('53388.105263157895')),
#  ('rosa', 'Sauber', 85, Decimal('4670855'), Decimal('54951.235294117647')),
#  ('rosa', 'McLaren', 102, Decimal('5605026'), Decimal('54951.235294117647')),
#  ('rosa', 'Jaguar', 17, Decimal('934171'), Decimal('54951.235294117647')),
#  ('rosa', 'Arrows', 34, Decimal('1868342'), Decimal('54951.235294117647')),
#  ('rosa', 'HRT', 17, Decimal('934171'), Decimal('54951.235294117647')),
#  ('petrov', 'Caterham', 74, Decimal('4122784'), Decimal('55713.297297297297')),
#  ('petrov', 'Renault', 518, Decimal('28859488'), Decimal('55713.297297297297')),
#  ('trulli', 'Prost', 119, Decimal('6678329'), Decimal('56120.411764705882')),
#  ('trulli', 'Renault', 357, Decimal('20034987'), Decimal('56120.411764705882')),
#  ('trulli', 'Toyota', 714, Decimal('40069974'), Decimal('56120.411764705882')),
#  ('trulli', 'Jordan', 153, Decimal('8586423'), Decimal('56120.411764705882')),
#  ('trulli', 'Lotus', 17, Decimal('954047'), Decimal('56120.411764705882')),
#  ('bruno_senna', 'Williams', 338, Decimal('18983276'), Decimal('56163.538461538462')),
#  ('bruno_senna', 'Renault', 52, Decimal('2920504'), Decimal('56163.538461538462')),
#  ('alguersuari', 'Toro Rosso', 252, Decimal('14365134'), Decimal('57004.500000000000')),
#  ('heidfeld', 'Sauber', 100, Decimal('5733330'), Decimal('57333.300000000000')),
#  ('heidfeld', 'Williams', 50, Decimal('2866665'), Decimal('57333.300000000000'))]
